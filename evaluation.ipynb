# %%
import matplotlib.pyplot as plt


n = [10, 100, 1000, 10000, 100000]
depths = [5.5, 13.4, 21.7667, 31.05, 40.38]


plt.figure(figsize=(8, 6))
plt.plot(n, depths, marker='o', linestyle='-', color='b', label='Dubina stabla')

x = np.linspace(10, 100000, 100)  
y_log = 9*np.log10(x)  

plt.plot(x, y_log, linestyle='-', color='r', label='9*log(n)')
# Postavke grafika
plt.xlabel('Broj elemenata $n$')
plt.ylabel('Dubina stabla $D$')
plt.xscale('log') 
plt.yscale('log')
plt.grid(True)
plt.title('Dubina stabla u zavisnosti od veličine stabla')
plt.legend()

plt.savefig('depths.png')
plt.tight_layout() 
plt.show()
